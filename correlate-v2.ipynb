# %% [markdown]
# # Prediction of emission reduction using multivariate correlation
#
# This file presents a worked example of multivariate correlation analysis as implemented in the `brsflufight_nerc2` package.
# The example in this file predicts the change $CO_2$ emissions due to the COVID-19 lockdown for the Energy sector in the UK.
#
# While this file shows in depth information about the intermediate steps and their motivation a minimal working example of the correlation framework is shown in [`minimal-correlation-example`](minimal-correlation-example.ipynb). This minimal example serves to illustrate the extensibility of this framework to other data sources.
# The datasets used in this notebook are available in directory [`data/processed`](data/processed), and are generated by the notebooks in folder [`data/`](data/); in addition the notebook [`data_viz`](data_viz.ipynb)
# provides visualisation of those datasets.
#
# The correlation framework follows 3 steps:
#
# + data preparation (extraction and combination)
# + correlation;
# + and prediction.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
from matplotlib import pyplot as plt
import math

# %%
from IPython.display import display, Markdown

# %%
import brsflufight_nerc2  as bff2

# %% [markdown]
# ## Prepare data

# %%
data_sets = bff2.load_data_files()
# Out:
# WARNING: "example_air_quality_file.csv" not found in dictionary `file_read_functions`.
# A loading function must be defined in `data_access.default_file_read_functions`.
# WARNING: "no2_by_pua.csv" not found in dictionary `file_read_functions`.
# A loading function must be defined in `data_access.default_file_read_functions`.
# WARNING: "o3_by_pua.csv" not found in dictionary `file_read_functions`.
# A loading function must be defined in `data_access.default_file_read_functions`.
# WARNING: "pm10_by_pua.csv" not found in dictionary `file_read_functions`.
# A loading function must be defined in `data_access.default_file_read_functions`.
# WARNING: "PublicData_Countries_v6.xlsx" not found in dictionary `file_read_functions`.
# A loading function must be defined in `data_access.default_file_read_functions`.
# WARNING: "so2_by_pua.csv" not found in dictionary `file_read_functions`.
# A loading function must be defined in `data_access.default_file_read_functions`.

# %% [markdown]
# Data is loaded into a `DataGroup` which is simply a dictionary which exposes the method `get_country`.

# %%
country = 'United Kingdom'

d_uk = data_sets.get_country(country)
# Out:
# Success: historical_GHG_Sectors_GCP
# Success: historical_GHG_Sectors_PIK
# Success: historical_GHG_Sectors_UNFCCC
# Success: mobility_apple
# Failed: United Kingdom not in mobility_citymapper
# Success: mobility_google
# Success: uk_energy_daily
# Success: uk_energy_demand_reduction

# %% [markdown]
# ### Prepare yearly energy data
#
# For the energy we get the data for which we have full years of data and get the average power. We drop years with incomplete data (i.e. 2011  and 2020).

# %%
d_uk['uk_energy_yearly'] = bff2.summarise_to_freq(
    d_uk['uk_energy_daily'],
    freq='1Y', 
    fun_test_data=lambda gr: gr.count()["dayofyear"]>350,
)

# %% [markdown]
# ### Prepare yearly energy forecast for 2020
#
# In order to predict GHG emissions, the energy use is forecasted for 2020 on the basis of daily consumptions and a
# seasonality model.

# %%
d_uk['uk_energy_demand_reduction'].plot(y=data_sets['uk_energy_demand_reduction'].data_columns)

# %% [markdown]
# For the modelling this data needs to be averaged for the year:

# %%
d_uk['uk_energy_demand_reduction_yearly'] = bff2.summarise_to_freq(
    d_uk['uk_energy_demand_reduction'], freq='1Y', fun_test_data=None
)

# %%
d_uk['uk_energy_demand_reduction_yearly'].head()
# Out:
#             energy_demand_with_corona  energy_demand_without_corona  \
# timestamp
# 2020-01-01               28061.809075                  31803.739168
#
#             energy_demand_reduction
# timestamp
# 2020-01-01              3741.930094

# %% [markdown]
# ### Prepare combined column

# %%
d_uk['historical_GHG_Sectors_GCP']['Gas and Coal (CO2)'] = \
    d_uk['historical_GHG_Sectors_GCP']['Gas (CO2)'] + d_uk['historical_GHG_Sectors_GCP']['Coal (CO2)']

# %% [markdown]
# ## Correlating datasets
#
# ### Choice of datasets

# %% [markdown]
# First we define the datasets and the columns we want to correlate. Implicitely we are emitting the hypothesis:
#
# *Column C in dataset X is correlated to column D in dataset Y.*
#
# for all columns and datasets in the dictionary `to_correlate`.

# %%
to_correlate = {
    'uk_energy_yearly': ['oil', 'ccgt', 'coal', 'demand'],  # Carbon intensive energy sources
    'historical_GHG_Sectors_GCP': [  # Select only CO2 data not other gases
        s for s in d_uk['historical_GHG_Sectors_GCP'].columns if f"(CO2)" in s
    ],
    'historical_GHG_Sectors_PIK': [  # Select Energy data not other sectors
        'Energy (KYOTOGHG)', 'Energy (CO2)', 'Energy (N2O)', 'Energy (CH4)'
    ],
}

# %% [markdown]
# For this work we are correlating three datasets:
#
# + `'uk_energy_yearly'` The average yearly power consomption of the UK by type of power station.
# + `'historical_GHG_Sectors_GCP'` the global carbon project's breakdown of yearly carbon emissions by fossil fuel.
# + `'historical_GHG_Sectors_PIK'` The Potsdam Institute for climate change impact research (PIK) breakdown of yearly carbon emissions by sector of the economy.
#
# The first 3 lines are displayed in the subsections below:

# %%
for d in to_correlate:
    display(Markdown(f"#### dataset `'{d}'`'"))
    display(d_uk[d].tail(3))
# Out:
# #### dataset `'uk_energy_yearly'`'
#                   demand         coal      nuclear          ccgt         wind  \
# timestamp
# 2017-01-01  31858.397066  2357.162886  7484.045780  13678.825019  3689.535314
# 2018-01-01  31458.583256  1764.089781  6923.616315  13205.261560  4498.223694
# 2019-01-01  30606.290673   679.510313  6022.150777  13080.728889  5302.395747
#
#                 pumped       hydro      biomass       oil        solar  \
# timestamp
# 2017-01-01  316.498433  457.617018  1627.341894  0.000000  1189.161055
# 2018-01-01  271.923046  366.609060  1840.524415  0.004410  1248.855466
# 2019-01-01  195.267497  408.815841  1965.136313  0.011887  1230.144531
#
#                 ocgt      other  dayofyear
# timestamp
# 2017-01-01  1.890384  14.902725      183.0
# 2018-01-01  2.098168  81.660209      183.0
# 2019-01-01  7.983079  88.507691      183.0
# #### dataset `'historical_GHG_Sectors_GCP'`'
#                    Country       date Data source    Unit  Bunkers (CO2)  \
# date
# 2016-01-01  United Kingdom 2016-01-01         GCP  MtCO₂e            NaN
# 2017-01-01  United Kingdom 2017-01-01         GCP  MtCO₂e            NaN
# 2018-01-01  United Kingdom 2018-01-01         GCP  MtCO₂e            NaN
#
#             Cement (CO2)  Coal (CO2)  Gas (CO2)  Gas flaring (CO2)  Oil (CO2)  \
# date
# 2016-01-01          4.55       47.10     165.77               4.52     175.19
# 2017-01-01          4.41       38.44     161.79               4.59     175.37
# 2018-01-01          4.41       32.07     161.92               4.59     173.26
#
#             Total fossil fuels and cement (CO2)  Gas and Coal (CO2)
# date
# 2016-01-01                               399.84              212.87
# 2017-01-01                               387.39              200.23
# 2018-01-01                               379.04              193.99
# #### dataset `'historical_GHG_Sectors_PIK'`'
#                    Country       date Data source    Unit  Agriculture (CH4)  \
# date
# 2015-01-01  United Kingdom 2015-01-01         PIK  MtCO₂e              25.75
# 2016-01-01  United Kingdom 2016-01-01         PIK  MtCO₂e              25.75
# 2017-01-01  United Kingdom 2017-01-01         PIK  MtCO₂e              26.00
#
#             Energy (CH4)  Industrial Processes and Product Use (CH4)  \
# date
# 2015-01-01          7.90                                        0.08
# 2016-01-01          6.98                                        0.09
# 2017-01-01          7.00                                        0.08
#
#             Other (CH4)  Total excluding LULUCF (CH4)  Waste (CH4)  ...  \
# date                                                                ...
# 2015-01-01          NaN                          53.0        19.33  ...
# 2016-01-01          NaN                          51.5        18.65  ...
# 2017-01-01          NaN                          52.0        18.90  ...
#
#             Total excluding LULUCF (KYOTOGHG)  Waste (KYOTOGHG)  \
# date
# 2015-01-01                              520.0              21.0
# 2016-01-01                              495.0              20.4
# 2017-01-01                              482.0              20.7
#
#             Agriculture (N2O)  Energy (N2O)  \
# date
# 2015-01-01              14.10          2.62
# 2016-01-01              14.10          2.49
# 2017-01-01              14.36          2.51
#
#             Industrial Processes and Product Use (N2O)  Other (N2O)  \
# date
# 2015-01-01                                        0.85         1.18
# 2016-01-01                                        0.86         1.12
# 2017-01-01                                        0.89         1.07
#
#             Total excluding LULUCF (N2O)  Waste (N2O)  \
# date
# 2015-01-01                         20.17         1.42
# 2016-01-01                         20.03         1.46
# 2017-01-01                         20.35         1.49
#
#             Industrial Processes and Product Use (F-Gas)  \
# date
# 2015-01-01                                          16.0
# 2016-01-01                                          15.2
# 2017-01-01                                          14.2
#
#             Total excluding LULUCF (F-Gas)
# date
# 2015-01-01                            16.0
# 2016-01-01                            15.2
# 2017-01-01                            14.2
#
# [3 rows x 30 columns]

# %% [markdown]
# ### Calculating correlations

# %% [markdown]
# Once chosen we pass it to function [`correlate`](brsflufight_nerc2/model_predict.py)
# which calculates and returns correlations between columns of the datasets in `selector` and the dataset defined by `main_compare`. Linear fits for each correlation are also computed.

# %%
correlation_dict = bff2.correlate(
    selector=to_correlate,  # datasets defined above
    data_sets=d_uk,  # UK data
    main_compare='uk_energy_yearly',  # reference dataset, the other are correlated to it
)
# Out:
# Linear regression failed for: 'Bunkers (CO2)' fit to  'oil':
#   Message: Input contains NaN, infinity or a value too large for dtype('float64').
# Linear regression failed for: 'Bunkers (CO2)' fit to  'ccgt':
#   Message: Input contains NaN, infinity or a value too large for dtype('float64').
# Linear regression failed for: 'Bunkers (CO2)' fit to  'coal':
#   Message: Input contains NaN, infinity or a value too large for dtype('float64').
# Linear regression failed for: 'Bunkers (CO2)' fit to  'demand':
#   Message: Input contains NaN, infinity or a value too large for dtype('float64').

# %% [markdown]
# `bff2.correlate` returns a dictionary of dictionaries corresponding to the datasets that were correlated to `main_compare` (in this case `'uk_energy_yearly'`).
# For each dataset 3 items are returned:
#
#   + a `'correlation'`: the pearson correlation coefficient between datasets;
#   + the merged `'data'` used for the correlation;
#   + a linear `'fit'` between the datasets done through `scikit-learn` `LinearRegression`;
#
# We can visualise the correlations to identify relationships of interest, we are looking for numbers close to 1.

# %%
bff2.display_correlations(correlation_dict, display_fun=display)
# Out:
# =====================================================================
# Pearson correlation coefficients in dataset 'historical_GHG_Sectors_GCP'
# 	 on data from 2012 to 2018 (inclusive)
# _________________________________________________________
# <style  type="text/css" >
#     #T_37105568_b78d_11ea_80c8_f8e4e3d5f2f4row0_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_37105568_b78d_11ea_80c8_f8e4e3d5f2f4row0_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_37105568_b78d_11ea_80c8_f8e4e3d5f2f4row0_col2 {
#             background-color:  #034973;
#             color:  #f1f1f1;
#         }    #T_37105568_b78d_11ea_80c8_f8e4e3d5f2f4row0_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_37105568_b78d_11ea_80c8_f8e4e3d5f2f4row0_col4 {
#             background-color:  #f6eff7;
#             color:  #000000;
#         }    #T_37105568_b78d_11ea_80c8_f8e4e3d5f2f4row0_col5 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_37105568_b78d_11ea_80c8_f8e4e3d5f2f4row0_col6 {
#             background-color:  #034973;
#             color:  #f1f1f1;
#         }    #T_37105568_b78d_11ea_80c8_f8e4e3d5f2f4row0_col7 {
#             background-color:  #034973;
#             color:  #f1f1f1;
#         }    #T_37105568_b78d_11ea_80c8_f8e4e3d5f2f4row1_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_37105568_b78d_11ea_80c8_f8e4e3d5f2f4row1_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_37105568_b78d_11ea_80c8_f8e4e3d5f2f4row1_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_37105568_b78d_11ea_80c8_f8e4e3d5f2f4row1_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_37105568_b78d_11ea_80c8_f8e4e3d5f2f4row1_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_37105568_b78d_11ea_80c8_f8e4e3d5f2f4row1_col5 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_37105568_b78d_11ea_80c8_f8e4e3d5f2f4row1_col6 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_37105568_b78d_11ea_80c8_f8e4e3d5f2f4row1_col7 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_37105568_b78d_11ea_80c8_f8e4e3d5f2f4row2_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_37105568_b78d_11ea_80c8_f8e4e3d5f2f4row2_col1 {
#             background-color:  #f1ebf5;
#             color:  #000000;
#         }    #T_37105568_b78d_11ea_80c8_f8e4e3d5f2f4row2_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_37105568_b78d_11ea_80c8_f8e4e3d5f2f4row2_col3 {
#             background-color:  #faf3f9;
#             color:  #000000;
#         }    #T_37105568_b78d_11ea_80c8_f8e4e3d5f2f4row2_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_37105568_b78d_11ea_80c8_f8e4e3d5f2f4row2_col5 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_37105568_b78d_11ea_80c8_f8e4e3d5f2f4row2_col6 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_37105568_b78d_11ea_80c8_f8e4e3d5f2f4row2_col7 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_37105568_b78d_11ea_80c8_f8e4e3d5f2f4row3_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_37105568_b78d_11ea_80c8_f8e4e3d5f2f4row3_col1 {
#             background-color:  #f1ebf5;
#             color:  #000000;
#         }    #T_37105568_b78d_11ea_80c8_f8e4e3d5f2f4row3_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_37105568_b78d_11ea_80c8_f8e4e3d5f2f4row3_col3 {
#             background-color:  #faf3f9;
#             color:  #000000;
#         }    #T_37105568_b78d_11ea_80c8_f8e4e3d5f2f4row3_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_37105568_b78d_11ea_80c8_f8e4e3d5f2f4row3_col5 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_37105568_b78d_11ea_80c8_f8e4e3d5f2f4row3_col6 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_37105568_b78d_11ea_80c8_f8e4e3d5f2f4row3_col7 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }</style><table id="T_37105568_b78d_11ea_80c8_f8e4e3d5f2f4" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Bunkers (CO2)</th>        <th class="col_heading level0 col1" >Cement (CO2)</th>        <th class="col_heading level0 col2" >Coal (CO2)</th>        <th class="col_heading level0 col3" >Gas (CO2)</th>        <th class="col_heading level0 col4" >Gas flaring (CO2)</th>        <th class="col_heading level0 col5" >Oil (CO2)</th>        <th class="col_heading level0 col6" >Total fossil fuels and cement (CO2)</th>        <th class="col_heading level0 col7" >Gas and Coal (CO2)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_37105568_b78d_11ea_80c8_f8e4e3d5f2f4level0_row0" class="row_heading level0 row0" >oil</th>
#                         <td id="T_37105568_b78d_11ea_80c8_f8e4e3d5f2f4row0_col0" class="data row0 col0" >nan</td>
#                         <td id="T_37105568_b78d_11ea_80c8_f8e4e3d5f2f4row0_col1" class="data row0 col1" >-0.845</td>
#                         <td id="T_37105568_b78d_11ea_80c8_f8e4e3d5f2f4row0_col2" class="data row0 col2" >0.883</td>
#                         <td id="T_37105568_b78d_11ea_80c8_f8e4e3d5f2f4row0_col3" class="data row0 col3" >-0.613</td>
#                         <td id="T_37105568_b78d_11ea_80c8_f8e4e3d5f2f4row0_col4" class="data row0 col4" >-0.700</td>
#                         <td id="T_37105568_b78d_11ea_80c8_f8e4e3d5f2f4row0_col5" class="data row0 col5" >-0.883</td>
#                         <td id="T_37105568_b78d_11ea_80c8_f8e4e3d5f2f4row0_col6" class="data row0 col6" >0.883</td>
#                         <td id="T_37105568_b78d_11ea_80c8_f8e4e3d5f2f4row0_col7" class="data row0 col7" >0.883</td>
#             </tr>
#             <tr>
#                         <th id="T_37105568_b78d_11ea_80c8_f8e4e3d5f2f4level0_row1" class="row_heading level0 row1" >ccgt</th>
#                         <td id="T_37105568_b78d_11ea_80c8_f8e4e3d5f2f4row1_col0" class="data row1 col0" >nan</td>
#                         <td id="T_37105568_b78d_11ea_80c8_f8e4e3d5f2f4row1_col1" class="data row1 col1" >0.739</td>
#                         <td id="T_37105568_b78d_11ea_80c8_f8e4e3d5f2f4row1_col2" class="data row1 col2" >-0.786</td>
#                         <td id="T_37105568_b78d_11ea_80c8_f8e4e3d5f2f4row1_col3" class="data row1 col3" >0.643</td>
#                         <td id="T_37105568_b78d_11ea_80c8_f8e4e3d5f2f4row1_col4" class="data row1 col4" >0.487</td>
#                         <td id="T_37105568_b78d_11ea_80c8_f8e4e3d5f2f4row1_col5" class="data row1 col5" >0.857</td>
#                         <td id="T_37105568_b78d_11ea_80c8_f8e4e3d5f2f4row1_col6" class="data row1 col6" >-0.786</td>
#                         <td id="T_37105568_b78d_11ea_80c8_f8e4e3d5f2f4row1_col7" class="data row1 col7" >-0.786</td>
#             </tr>
#             <tr>
#                         <th id="T_37105568_b78d_11ea_80c8_f8e4e3d5f2f4level0_row2" class="row_heading level0 row2" >coal</th>
#                         <td id="T_37105568_b78d_11ea_80c8_f8e4e3d5f2f4row2_col0" class="data row2 col0" >nan</td>
#                         <td id="T_37105568_b78d_11ea_80c8_f8e4e3d5f2f4row2_col1" class="data row2 col1" >-0.703</td>
#                         <td id="T_37105568_b78d_11ea_80c8_f8e4e3d5f2f4row2_col2" class="data row2 col2" >1.000</td>
#                         <td id="T_37105568_b78d_11ea_80c8_f8e4e3d5f2f4row2_col3" class="data row2 col3" >-0.571</td>
#                         <td id="T_37105568_b78d_11ea_80c8_f8e4e3d5f2f4row2_col4" class="data row2 col4" >-0.775</td>
#                         <td id="T_37105568_b78d_11ea_80c8_f8e4e3d5f2f4row2_col5" class="data row2 col5" >-0.786</td>
#                         <td id=
# =====================================================================
#
# =====================================================================
# Pearson correlation coefficients in dataset 'historical_GHG_Sectors_PIK'
# 	 on data from 2012 to 2017 (inclusive)
# _________________________________________________________
# <style  type="text/css" >
#     #T_371536f4_b78d_11ea_8d22_f8e4e3d5f2f4row0_col0 {
#             background-color:  #023a5b;
#             color:  #f1f1f1;
#         }    #T_371536f4_b78d_11ea_8d22_f8e4e3d5f2f4row0_col1 {
#             background-color:  #023a5b;
#             color:  #f1f1f1;
#         }    #T_371536f4_b78d_11ea_8d22_f8e4e3d5f2f4row0_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_371536f4_b78d_11ea_8d22_f8e4e3d5f2f4row0_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_371536f4_b78d_11ea_8d22_f8e4e3d5f2f4row1_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_371536f4_b78d_11ea_8d22_f8e4e3d5f2f4row1_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_371536f4_b78d_11ea_8d22_f8e4e3d5f2f4row1_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_371536f4_b78d_11ea_8d22_f8e4e3d5f2f4row1_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_371536f4_b78d_11ea_8d22_f8e4e3d5f2f4row2_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_371536f4_b78d_11ea_8d22_f8e4e3d5f2f4row2_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_371536f4_b78d_11ea_8d22_f8e4e3d5f2f4row2_col2 {
#             background-color:  #023e62;
#             color:  #f1f1f1;
#         }    #T_371536f4_b78d_11ea_8d22_f8e4e3d5f2f4row2_col3 {
#             background-color:  #023d60;
#             color:  #f1f1f1;
#         }    #T_371536f4_b78d_11ea_8d22_f8e4e3d5f2f4row3_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_371536f4_b78d_11ea_8d22_f8e4e3d5f2f4row3_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_371536f4_b78d_11ea_8d22_f8e4e3d5f2f4row3_col2 {
#             background-color:  #023e62;
#             color:  #f1f1f1;
#         }    #T_371536f4_b78d_11ea_8d22_f8e4e3d5f2f4row3_col3 {
#             background-color:  #023d60;
#             color:  #f1f1f1;
#         }</style><table id="T_371536f4_b78d_11ea_8d22_f8e4e3d5f2f4" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Energy (KYOTOGHG)</th>        <th class="col_heading level0 col1" >Energy (CO2)</th>        <th class="col_heading level0 col2" >Energy (N2O)</th>        <th class="col_heading level0 col3" >Energy (CH4)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_371536f4_b78d_11ea_8d22_f8e4e3d5f2f4level0_row0" class="row_heading level0 row0" >oil</th>
#                         <td id="T_371536f4_b78d_11ea_8d22_f8e4e3d5f2f4row0_col0" class="data row0 col0" >0.986</td>
#                         <td id="T_371536f4_b78d_11ea_8d22_f8e4e3d5f2f4row0_col1" class="data row0 col1" >0.986</td>
#                         <td id="T_371536f4_b78d_11ea_8d22_f8e4e3d5f2f4row0_col2" class="data row0 col2" >0.812</td>
#                         <td id="T_371536f4_b78d_11ea_8d22_f8e4e3d5f2f4row0_col3" class="data row0 col3" >0.986</td>
#             </tr>
#             <tr>
#                         <th id="T_371536f4_b78d_11ea_8d22_f8e4e3d5f2f4level0_row1" class="row_heading level0 row1" >ccgt</th>
#                         <td id="T_371536f4_b78d_11ea_8d22_f8e4e3d5f2f4row1_col0" class="data row1 col0" >-0.829</td>
#                         <td id="T_371536f4_b78d_11ea_8d22_f8e4e3d5f2f4row1_col1" class="data row1 col1" >-0.829</td>
#                         <td id="T_371536f4_b78d_11ea_8d22_f8e4e3d5f2f4row1_col2" class="data row1 col2" >-0.829</td>
#                         <td id="T_371536f4_b78d_11ea_8d22_f8e4e3d5f2f4row1_col3" class="data row1 col3" >-0.886</td>
#             </tr>
#             <tr>
#                         <th id="T_371536f4_b78d_11ea_8d22_f8e4e3d5f2f4level0_row2" class="row_heading level0 row2" >coal</th>
#                         <td id="T_371536f4_b78d_11ea_8d22_f8e4e3d5f2f4row2_col0" class="data row2 col0" >1.000</td>
#                         <td id="T_371536f4_b78d_11ea_8d22_f8e4e3d5f2f4row2_col1" class="data row2 col1" >1.000</td>
#                         <td id="T_371536f4_b78d_11ea_8d22_f8e4e3d5f2f4row2_col2" class="data row2 col2" >0.771</td>
#                         <td id="T_371536f4_b78d_11ea_8d22_f8e4e3d5f2f4row2_col3" class="data row2 col3" >0.943</td>
#             </tr>
#             <tr>
#                         <th id="T_371536f4_b78d_11ea_8d22_f8e4e3d5f2f4level0_row3" class="row_heading level0 row3" >demand</th>
#                         <td id="T_371536f4_b78d_11ea_8d22_f8e4e3d5f2f4row3_col0" class="data row3 col0" >1.000</td>
#                         <td id="T_371536f4_b78d_11ea_8d22_f8e4e3d5f2f4row3_col1" class="data row3 col1" >1.000</td>
#                         <td id="T_371536f4_b78d_11ea_8d22_f8e4e3d5f2f4row3_col2" class="data row3 col2" >0.771</td>
#                         <td id="T_371536f4_b78d_11ea_8d22_f8e4e3d5f2f4row3_col3" class="data row3 col3" >0.943</td>
#             </tr>
#     </tbody></table>
# =====================================================================

# %% [markdown]
# Before predicting the emissions based on GHG let us check what the data from which we predict is like

# %% [markdown]
# ### Refining dataset and column selections
#
# Not all these relationships will enable prediction of GHG emissions. In the subsections below
# correlations between GHG emissions and: closed cycle gas turbine power stations (`'ccgt'`), coal power stations (`'coal'`) and, fuel power stations (`'fuel'`); are discussed.
#
# #### Rejecting `'ccgt'`
#
# 'Combine cycle gas turbine' used is inversely correlated with GHG emissions. This is because
# there are two drivers of the long term trend in GHG emissions reduction due to the energy sector:
#
# + Transition to cleaner fossil fuel sources of power ('ccgt' rather than 'coal');
# + Reduction in 'demand';
# + And increase in renewables.
#
# A possibly exploitable correlation can be seen with the global carbon project dataset, specifically gas use. For the purpose of this prototype this was not done, and the power produced by `'ccgt'` are not used.

# %% [markdown]
# #### Rejecting `'oil'`
#
# Plotting the '`oil`' data, shows that despite high correlation it is 4 orders of magnitude lower than the other power generation methods. This suggests that the correlation is not significant.

# %%
dsource = 'uk_energy_yearly'
d_uk[dsource].plot(y=to_correlate[dsource])
d_uk[dsource][to_correlate[dsource]].describe()
# Out:
#             oil          ccgt          coal        demand
# count  8.000000      8.000000      8.000000      8.000000
# mean   0.508933  11579.530732   7192.968170  33331.404544
# std    0.796658   2229.139008   5982.333526   2221.087664
# min    0.000000   9148.029085    679.510313  30606.290673
# 25%    0.003308   9603.858167   2208.894609  31758.443613
# 50%    0.154770  11489.689029   5852.376027  32712.718536
# 75%    0.650764  13323.652425  11866.890665  34907.808907
# max    2.309853  14506.012432  15641.439384  36581.013455

# %% [markdown]
# #### Rejecting `'coal'`

# %% [markdown]
# Because 'coal' plants are stopped preferentially data is truncated from mid-April in 2020 as they have not been in use. This implies that some of the lockdown impact will be missed at least when using the PIK GHG emission dataset.
#
# Indeed the global carbon project (GCP) includes data broken down by fuel. While not all those emissions will be the energy sector strong correlations can still be observed. These metrics can also be predicted using the same framework.
#
# Because of this truncation `'coal'` is not used for predictions.

# %%
d_uk['uk_energy_daily'].loc[d_uk['uk_energy_daily'].index >= "2019", to_correlate[dsource]].plot(y='coal')

# %% [markdown]
# ## Predicting GHG emissions from the Energy sector from energy demand
#
# From the correlations emissions are predicted based on the
# data from the Potsdam institute for climate impact research (PIK) ([Gütschow et al., 2016,](http://doi.org/10.5194/essd-8-571-2016)) (called '`historical_GHG_Sectors_PIK`' in our framework, [data download](https://dataservices.gfz-potsdam.de/pik/showshort.php?id=escidoc:4736895)) using specifically:
#
# + 'demand' : The average yearly power demand;
#
# In order to predict emissions, this quantity needs to be
# These values are predicted in [`predict.ipynb`]()

# %%
prediction_data_set = correlation_dict['historical_GHG_Sectors_GCP']

# %% [markdown]
# ### Example prediction on the avilable data

# %%
df = d_uk['uk_energy_yearly']
pred_x = df.loc[
    (df.index >= "2010") & (df.index < "2020"), ["demand", "ccgt", "coal"]
]
pred_x
# Out:
#                   demand          ccgt          coal
# timestamp
# 2012-01-01  36581.013455   9470.393216  15641.439384
# 2013-01-01  36266.654436   9148.029085  14361.405081
# 2014-01-01  34454.860398   9898.649169  11035.385859
# 2015-01-01  33048.731071   9648.346483   8508.842895
# 2016-01-01  32376.706000  14506.012432   3195.909159
# 2017-01-01  31858.397066  13678.825019   2357.162886
# 2018-01-01  31458.583256  13205.261560   1764.089781
# 2019-01-01  30606.290673  13080.728889    679.510313

# %% [markdown]
# Using function `bff2.apply_prediction` applies the linear prediction to each correlated column

# %%
pred = bff2.apply_prediction(prediction_data_set['fit'], pred_x)
pred
# Out:
#                       predictor_value  Bunkers (CO2)  Cement (CO2)  \
# predictor date
# demand    2012-01-01     36581.013455            NaN      3.891558
#           2013-01-01     36266.654436            NaN      3.931423
#           2014-01-01     34454.860398            NaN      4.161184
#           2015-01-01     33048.731071            NaN      4.339502
#           2016-01-01     32376.706000            NaN      4.424724
#           2017-01-01     31858.397066            NaN      4.490453
#           2018-01-01     31458.583256            NaN      4.541156
#           2019-01-01     30606.290673            NaN      4.649239
# ccgt      2012-01-01      9470.393216            NaN      4.088739
#           2013-01-01      9148.029085            NaN      4.060572
#           2014-01-01      9898.649169            NaN      4.126157
#           2015-01-01      9648.346483            NaN      4.104287
#           2016-01-01     14506.012432            NaN      4.528724
#           2017-01-01     13678.825019            NaN      4.456449
#           2018-01-01     13205.261560            NaN      4.415072
#           2019-01-01     13080.728889            NaN      4.404191
# coal      2012-01-01     15641.439384            NaN      3.926277
#           2013-01-01     14361.405081            NaN      3.982125
#           2014-01-01     11035.385859            NaN      4.127239
#           2015-01-01      8508.842895            NaN      4.237472
#           2016-01-01      3195.909159            NaN      4.469274
#           2017-01-01      2357.162886            NaN      4.505869
#           2018-01-01      1764.089781            NaN      4.531744
#           2019-01-01       679.510313            NaN      4.579065
#
#                       Coal (CO2)   Gas (CO2)  Gas flaring (CO2)   Oil (CO2)  \
# predictor date
# demand    2012-01-01  154.049802  152.786774           3.941956  167.952562
#           2013-01-01  146.782504  153.188278           3.987587  168.341183
#           2014-01-01  104.897758  155.502328           4.250577  170.580985
#           2015-01-01   72.391100  157.298257           4.454683  172.319291
#           2016-01-01   56.855339  158.156577           4.552231  173.150071
#           2017-01-01   44.873162  158.818569           4.627466  173.790822
#           2018-01-01   35.630334  159.329217           4.685500  174.285086
#           2019-01-01   15.927180  160.417777           4.809214  175.338720
# ccgt      2012-01-01  124.842713  151.572785           4.193127  169.056218
#           2013-01-01  131.123833  150.744668           4.165221  168.642373
#           2014-01-01  116.498339  152.672925           4.230200  169.606004
#           2015-01-01  121.375374  152.029926           4.208532  169.284671
#           2016-01-01   26.725941  164.508708           4.629043  175.520847
#           2017-01-01   42.843315  162.383759           4.557436  174.458920
#           2018-01-01   52.070486  161.167229           4.516442  173.850968
#           2019-01-01   54.496949  160.847319           4.505661  173.691096
# coal      2012-01-01  151.790260  151.233853           3.991772  167.913881
#           2013-01-01  140.916483  152.120268           4.053981  168.522519
#           2014-01-01  112.662246  154.423513           4.215624  170.103993
#           2015-01-01   91.199489  156.173127           4.338413  171.305328
#           2016-01-01   46.066591  159.852296           4.596620  173.831552
#           2017-01-01   38.941517  160.433122           4.637383  174.230364
#           2018-01-01   33.903413  160.843821           4.666206  174.512362
#           2019-01-01   24.690008  161.594885           4.718916  175.028064
#
#                       Total fossil fuels and cement (CO2)  Gas and Coal (CO2)
# predictor date
# demand    2012-01-01                           486.115835          306.836576
#           2013-01-01                           479.680475          299.970782
#           2014-01-01                           442.590565          260.400086
#           2015-01-01                           413.805169          229.689357
#           2016-01-01                           400.047894          215.011916
#           2017-01-01                           389.437399          203.691731
#           2018-01-01                           381.252662          194.959551
#           2019-01-01                           363.805064          176.344957
# ccgt      2012-01-01                           457.099865          276.415498
#           2013-01-01                           462.125584          281.868501
#           2014-01-01                           450.423272          269.171263
#           2015-01-01                           454.325539          273.405300
#           2016-01-01                           378.593590          191.234649
#           2017-01-01                           391.489602          205.227074
#           2018-01-01                           398.872547          213.237715
#           2019-01-01                           400.814036          215.344268
# coal      2012-01-01                           482.352651          303.024113
#           2013-01-01                           473.023726          293.036751
#           2014-01-01                           448.783608          267.085759
#           2015-01-01                           430.370094          247.372616
#           2016-01-01                           391.649288          205.918887
#           2017-01-01                           385.536483          199.374639
#           2018-01-01                           381.214150          194.747235
#           2019-01-01                           373.309705          186.284892

# %% [markdown]
# It is useful to check here what the correlations between predictors (rows) and predicted values are (columns)

# %%
display(
    prediction_data_set['correlation'].loc[pred.index.get_level_values(0).unique()]
    .style.background_gradient().set_precision(3)
)
# Out:
# <style  type="text/css" >
#     #T_61cafcd8_b78f_11ea_95a9_f8e4e3d5f2f4row0_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_61cafcd8_b78f_11ea_95a9_f8e4e3d5f2f4row0_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_61cafcd8_b78f_11ea_95a9_f8e4e3d5f2f4row0_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_61cafcd8_b78f_11ea_95a9_f8e4e3d5f2f4row0_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_61cafcd8_b78f_11ea_95a9_f8e4e3d5f2f4row0_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_61cafcd8_b78f_11ea_95a9_f8e4e3d5f2f4row0_col5 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_61cafcd8_b78f_11ea_95a9_f8e4e3d5f2f4row0_col6 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_61cafcd8_b78f_11ea_95a9_f8e4e3d5f2f4row0_col7 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_61cafcd8_b78f_11ea_95a9_f8e4e3d5f2f4row1_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_61cafcd8_b78f_11ea_95a9_f8e4e3d5f2f4row1_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_61cafcd8_b78f_11ea_95a9_f8e4e3d5f2f4row1_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_61cafcd8_b78f_11ea_95a9_f8e4e3d5f2f4row1_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_61cafcd8_b78f_11ea_95a9_f8e4e3d5f2f4row1_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_61cafcd8_b78f_11ea_95a9_f8e4e3d5f2f4row1_col5 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_61cafcd8_b78f_11ea_95a9_f8e4e3d5f2f4row1_col6 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_61cafcd8_b78f_11ea_95a9_f8e4e3d5f2f4row1_col7 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_61cafcd8_b78f_11ea_95a9_f8e4e3d5f2f4row2_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_61cafcd8_b78f_11ea_95a9_f8e4e3d5f2f4row2_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_61cafcd8_b78f_11ea_95a9_f8e4e3d5f2f4row2_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_61cafcd8_b78f_11ea_95a9_f8e4e3d5f2f4row2_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_61cafcd8_b78f_11ea_95a9_f8e4e3d5f2f4row2_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_61cafcd8_b78f_11ea_95a9_f8e4e3d5f2f4row2_col5 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_61cafcd8_b78f_11ea_95a9_f8e4e3d5f2f4row2_col6 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_61cafcd8_b78f_11ea_95a9_f8e4e3d5f2f4row2_col7 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }</style><table id="T_61cafcd8_b78f_11ea_95a9_f8e4e3d5f2f4" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Bunkers (CO2)</th>        <th class="col_heading level0 col1" >Cement (CO2)</th>        <th class="col_heading level0 col2" >Coal (CO2)</th>        <th class="col_heading level0 col3" >Gas (CO2)</th>        <th class="col_heading level0 col4" >Gas flaring (CO2)</th>        <th class="col_heading level0 col5" >Oil (CO2)</th>        <th class="col_heading level0 col6" >Total fossil fuels and cement (CO2)</th>        <th class="col_heading level0 col7" >Gas and Coal (CO2)</th>    </tr>    <tr>        <th class="index_name level0" >predictor</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_61cafcd8_b78f_11ea_95a9_f8e4e3d5f2f4level0_row0" class="row_heading level0 row0" >demand</th>
#                         <td id="T_61cafcd8_b78f_11ea_95a9_f8e4e3d5f2f4row0_col0" class="data row0 col0" >nan</td>
#                         <td id="T_61cafcd8_b78f_11ea_95a9_f8e4e3d5f2f4row0_col1" class="data row0 col1" >-0.703</td>
#                         <td id="T_61cafcd8_b78f_11ea_95a9_f8e4e3d5f2f4row0_col2" class="data row0 col2" >1.000</td>
#                         <td id="T_61cafcd8_b78f_11ea_95a9_f8e4e3d5f2f4row0_col3" class="data row0 col3" >-0.571</td>
#                         <td id="T_61cafcd8_b78f_11ea_95a9_f8e4e3d5f2f4row0_col4" class="data row0 col4" >-0.775</td>
#                         <td id="T_61cafcd8_b78f_11ea_95a9_f8e4e3d5f2f4row0_col5" class="data row0 col5" >-0.786</td>
#                         <td id="T_61cafcd8_b78f_11ea_95a9_f8e4e3d5f2f4row0_col6" class="data row0 col6" >1.000</td>
#                         <td id="T_61cafcd8_b78f_11ea_95a9_f8e4e3d5f2f4row0_col7" class="data row0 col7" >1.000</td>
#             </tr>
#             <tr>
#                         <th id="T_61cafcd8_b78f_11ea_95a9_f8e4e3d5f2f4level0_row1" class="row_heading level0 row1" >ccgt</th>
#                         <td id="T_61cafcd8_b78f_11ea_95a9_f8e4e3d5f2f4row1_col0" class="data row1 col0" >nan</td>
#                         <td id="T_61cafcd8_b78f_11ea_95a9_f8e4e3d5f2f4row1_col1" class="data row1 col1" >0.739</td>
#                         <td id="T_61cafcd8_b78f_11ea_95a9_f8e4e3d5f2f4row1_col2" class="data row1 col2" >-0.786</td>
#                         <td id="T_61cafcd8_b78f_11ea_95a9_f8e4e3d5f2f4row1_col3" class="data row1 col3" >0.643</td>
#                         <td id="T_61cafcd8_b78f_11ea_95a9_f8e4e3d5f2f4row1_col4" class="data row1 col4" >0.487</td>
#                         <td id="T_61cafcd8_b78f_11ea_95a9_f8e4e3d5f2f4row1_col5" class="data row1 col5" >0.857</td>
#                         <td id="T_61cafcd8_b78f_11ea_95a9_f8e4e3d5f2f4row1_col6" class="data row1 col6" >-0.786</td>
#                         <td id="T_61cafcd8_b78f_11ea_95a9_f8e4e3d5f2f4row1_col7" class="data row1 col7" >-0.786</td>
#             </tr>
#             <tr>
#                         <th id="T_61cafcd8_b78f_11ea_95a9_f8e4e3d5f2f4level0_row2" class="row_heading level0 row2" >coal</th>
#                         <td id="T_61cafcd8_b78f_11ea_95a9_f8e4e3d5f2f4row2_col0" class="data row2 col0" >nan</td>
#                         <td id="T_61cafcd8_b78f_11ea_95a9_f8e4e3d5f2f4row2_col1" class="data row2 col1" >-0.703</td>
#                         <td id="T_61cafcd8_b78f_11ea_95a9_f8e4e3d5f2f4row2_col2" class="data row2 col2" >1.000</td>
#                         <td id="T_61cafcd8_b78f_11ea_95a9_f8e4e3d5f2f4row2_col3" class="data row2 col3" >-0.571</td>
#                         <td id="T_61cafcd8_b78f_11ea_95a9_f8e4e3d5f2f4row2_col4" class="data row2 col4" >-0.775</td>
#                         <td id="T_61cafcd8_b78f_11ea_95a9_f8e4e3d5f2f4row2_col5" class="data row2 col5" >-0.786</td>
#                         <td id="T_61cafcd8_b78f_11ea_95a9_f8e4e3d5f2f4row2_col6" class="data row2 col6" >1.000</td>
#                         <td id="T_61cafcd8_b78f_11ea_95a9_f8e4e3d5f2f4row2_col7" class="data row2 col7" >1.000</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# Now let us check the prediction on the 'training set'

# %%
analysis_cols = ['Gas (CO2)', 'Coal (CO2)', 'Gas and Coal (CO2)']
indep_idx = ["ccgt", "coal", "demand"]

fig, axs = plt.subplots(1, 3)
fig.set_size_inches(15, 6)
axs = axs.flatten()

i = 0
preds = pd.DataFrame()
truths = pd.DataFrame()
for idx, analysis_col in zip(indep_idx, analysis_cols):
    mask_pred = (pred.loc[idx].index <= prediction_data_set['data'][analysis_col].index.max())
    truth = truth.loc[pred.loc[idx].index[mask_pred], analysis_cols]
    current_cols = [analysis_col]
    axs[i].set_title(f"'{analysis_col}' from '{idx}' \n(correlation: {prediction_data_set['correlation'].loc[idx, analysis_col]:.2})")
    axs[i].set_ylabel('CO2 emissions [MtCO2e]')
    pred.loc[idx, current_cols].plot(
        y=current_cols,
        ax=axs[i], label=[f"{c} - prediction" for c in current_cols],
        linestyle='--', marker='+'
    )
    truth[current_cols].plot(
        y=current_cols,
        ax=axs[i], label=[f"{c} - truth" for c in current_cols],
    )
    preds = pd.concat([preds, pred.loc[idx, current_cols].rename({c:f"{c} from {idx}" for c in current_cols}, axis='columns')])
    truths = pd.concat([truths, truth[current_cols].rename({c:f"{c} from {idx}" for c in current_cols}, axis='columns')])
    i += 1

# %% [markdown]
# As expected for the data sets with the highest correlation the fit is very good. as indicated by the graphs above and the percentage errors within the range $\pm 4$% for the KYOTOGHG and CO2 columns

# %%
preds = preds.groupby(level=0).first()
truths = truths.groupby(level=0).first()

# %%
err = (((preds - truths)/truths))
print("Percentage errors between prediction and truth")
display(err.style.format('{:,.2%}'.format))
# Out:
# Percentage errors between prediction and truth
# <style  type="text/css" >
# </style><table id="T_9d6af1dc_b793_11ea_bebb_f8e4e3d5f2f4" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Gas (CO2) from ccgt</th>        <th class="col_heading level0 col1" >Coal (CO2) from coal</th>        <th class="col_heading level0 col2" >Gas and Coal (CO2) from demand</th>    </tr>    <tr>        <th class="index_name level0" >date</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9d6af1dc_b793_11ea_bebb_f8e4e3d5f2f4level0_row0" class="row_heading level0 row0" >2012-01-01 00:00:00</th>
#                         <td id="T_9d6af1dc_b793_11ea_bebb_f8e4e3d5f2f4row0_col0" class="data row0 col0" >-3.82%</td>
#                         <td id="T_9d6af1dc_b793_11ea_bebb_f8e4e3d5f2f4row0_col1" class="data row0 col1" >2.59%</td>
#                         <td id="T_9d6af1dc_b793_11ea_bebb_f8e4e3d5f2f4row0_col2" class="data row0 col2" >0.42%</td>
#             </tr>
#             <tr>
#                         <th id="T_9d6af1dc_b793_11ea_bebb_f8e4e3d5f2f4level0_row1" class="row_heading level0 row1" >2013-01-01 00:00:00</th>
#                         <td id="T_9d6af1dc_b793_11ea_bebb_f8e4e3d5f2f4row1_col0" class="data row1 col0" >-3.98%</td>
#                         <td id="T_9d6af1dc_b793_11ea_bebb_f8e4e3d5f2f4row1_col1" class="data row1 col1" >-1.19%</td>
#                         <td id="T_9d6af1dc_b793_11ea_bebb_f8e4e3d5f2f4row1_col2" class="data row1 col2" >0.12%</td>
#             </tr>
#             <tr>
#                         <th id="T_9d6af1dc_b793_11ea_bebb_f8e4e3d5f2f4level0_row2" class="row_heading level0 row2" >2014-01-01 00:00:00</th>
#                         <td id="T_9d6af1dc_b793_11ea_bebb_f8e4e3d5f2f4row2_col0" class="data row2 col0" >6.16%</td>
#                         <td id="T_9d6af1dc_b793_11ea_bebb_f8e4e3d5f2f4row2_col1" class="data row2 col1" >-2.55%</td>
#                         <td id="T_9d6af1dc_b793_11ea_bebb_f8e4e3d5f2f4row2_col2" class="data row2 col2" >0.37%</td>
#             </tr>
#             <tr>
#                         <th id="T_9d6af1dc_b793_11ea_bebb_f8e4e3d5f2f4level0_row3" class="row_heading level0 row3" >2015-01-01 00:00:00</th>
#                         <td id="T_9d6af1dc_b793_11ea_bebb_f8e4e3d5f2f4row3_col0" class="data row3 col0" >3.28%</td>
#                         <td id="T_9d6af1dc_b793_11ea_bebb_f8e4e3d5f2f4row3_col1" class="data row3 col1" >-0.53%</td>
#                         <td id="T_9d6af1dc_b793_11ea_bebb_f8e4e3d5f2f4row3_col2" class="data row3 col2" >-3.85%</td>
#             </tr>
#             <tr>
#                         <th id="T_9d6af1dc_b793_11ea_bebb_f8e4e3d5f2f4level0_row4" class="row_heading level0 row4" >2016-01-01 00:00:00</th>
#                         <td id="T_9d6af1dc_b793_11ea_bebb_f8e4e3d5f2f4row4_col0" class="data row4 col0" >-0.76%</td>
#                         <td id="T_9d6af1dc_b793_11ea_bebb_f8e4e3d5f2f4row4_col1" class="data row4 col1" >-2.19%</td>
#                         <td id="T_9d6af1dc_b793_11ea_bebb_f8e4e3d5f2f4row4_col2" class="data row4 col2" >1.01%</td>
#             </tr>
#             <tr>
#                         <th id="T_9d6af1dc_b793_11ea_bebb_f8e4e3d5f2f4level0_row5" class="row_heading level0 row5" >2017-01-01 00:00:00</th>
#                         <td id="T_9d6af1dc_b793_11ea_bebb_f8e4e3d5f2f4row5_col0" class="data row5 col0" >0.37%</td>
#                         <td id="T_9d6af1dc_b793_11ea_bebb_f8e4e3d5f2f4row5_col1" class="data row5 col1" >1.30%</td>
#                         <td id="T_9d6af1dc_b793_11ea_bebb_f8e4e3d5f2f4row5_col2" class="data row5 col2" >1.73%</td>
#             </tr>
#             <tr>
#                         <th id="T_9d6af1dc_b793_11ea_bebb_f8e4e3d5f2f4level0_row6" class="row_heading level0 row6" >2018-01-01 00:00:00</th>
#                         <td id="T_9d6af1dc_b793_11ea_bebb_f8e4e3d5f2f4row6_col0" class="data row6 col0" >-0.46%</td>
#                         <td id="T_9d6af1dc_b793_11ea_bebb_f8e4e3d5f2f4row6_col1" class="data row6 col1" >5.72%</td>
#                         <td id="T_9d6af1dc_b793_11ea_bebb_f8e4e3d5f2f4row6_col2" class="data row6 col2" >0.50%</td>
#             </tr>
#             <tr>
#                         <th id="T_9d6af1dc_b793_11ea_bebb_f8e4e3d5f2f4level0_row7" class="row_heading level0 row7" >2019-01-01 00:00:00</th>
#                         <td id="T_9d6af1dc_b793_11ea_bebb_f8e4e3d5f2f4row7_col0" class="data row7 col0" >nan%</td>
#                         <td id="T_9d6af1dc_b793_11ea_bebb_f8e4e3d5f2f4row7_col1" class="data row7 col1" >nan%</td>
#                         <td id="T_9d6af1dc_b793_11ea_bebb_f8e4e3d5f2f4row7_col2" class="data row7 col2" >nan%</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ### Predicting 2020 with and without lockdowns
#
# Because 2020 is not finished we must model the expected average energy consumption with and without lockdowns.

# %%
pred_corona = d_uk['uk_energy_demand_reduction_yearly']
pred_corona
# Out:
#             energy_demand_with_corona  energy_demand_without_corona  \
# timestamp
# 2020-01-01               28061.809075                  31803.739168
#
#             energy_demand_reduction
# timestamp
# 2020-01-01              3741.930094

# %%
pred_corona.drop(["energy_demand_reduction"], axis='columns', inplace=True)

# %%
pred = bff2.apply_prediction(
    prediction_data_set['fit'],
    pred_corona,
    {c: 'demand' for c in pred_corona}
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-9a8ab486f140> in <module>
#       2     prediction_data_set['fit'],
#       3     pred_corona,
# ----> 4     {c: 'demand' for c in pred_corona}
#       5 )
#
# c:\Users\alexa\Documents\code\covid19\BristolFluFighters\Covid_Hackathon_2\brsflufight_nerc2\model_predict.py in apply_prediction(fit_df, x_values, x_col_map)
#     101         df_temp["predictor_value"] = x_values[col_pred]
#     102         for y_col in fit_df.columns:
# --> 103             df_temp[y_col] = fit_df.loc[x_col_map[col_pred], y_col].predict(
#     104                 x_values[col_pred].values.reshape(-1, 1)
#     105             )
#
# AttributeError: 'numpy.float64' object has no attribute 'predict'

# %%
difference = pred.loc["energy_demand_with_corona"]-pred.loc["energy_demand_without_corona"]
ratio = (difference)/pred.loc["energy_demand_without_corona"]

difference["quantity"] = "absolute difference"
ratio["quantity"] = "relative difference"

change_corona = pd.concat([difference,ratio])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-e7a89b9b4ecd> in <module>
# ----> 1 difference = pred.loc["energy_demand_with_corona"]-pred.loc["energy_demand_without_corona"]
#       2 ratio = (difference)/pred.loc["energy_demand_without_corona"]
#       3
#       4 difference["quantity"] = "absolute difference"
#       5 ratio["quantity"] = "relative difference"
#
# NameError: name 'pred' is not defined

# %%
print("Predicted GHG emissions based on energy demand:")
print("___________________________________________________")
display(pred)
print("")
print("")
print("Predicted change in GHG emissions based on energy demand:")
print("_____________________________________________________________")
display(change_corona)
# Out:
# Predicted GHG emissions based on energy demand:
# ___________________________________________________
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-1149a6fcbcd7> in <module>
#       1 print("Predicted GHG emissions based on energy demand:")
#       2 print("___________________________________________________")
# ----> 3 display(pred)
#       4 print("")
#       5 print("")
#
# NameError: name 'pred' is not defined

# %% [markdown]
# ## Outcomes
#
# From this framework the predicted reduction in GHG emissions for the energy sector is:
#
# + from column `'Energy (KYOTOGHG)'` above: $77\ [MtCO_2e]$ (Megatons of $CO_2$ equivalent);
# + it corresponds to a 20% reduction of emissions for the sector due to a fall in demand of 12%.
#
# This observation suggests that demand reduction will provide an effective route to de-carbonisation: for each
# point of demand lost, almost two points of emissions are lost for the sector.
#
# ### Correlation framework
#
# While this file provided a worked example of correlating two datasets a minimal working example
# of the correlation framework is presented in [`minimal-correlation-example`](minimal-correlation-example.ipynb).
# In this file the process is summarised to 4 key actions:
#
# + data extraction;
# + data combination;
# + correlation;
# + and prediction.
