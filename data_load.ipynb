# %% [markdown]
# # Import pre-processed datasets
#
# This notebook imports the preprocessed datasets which come with this repository.
#
# This is now deprecated into [`data_access.py`](brsflufight_nerc2/data_access.py) (which was created by exporting this file).

# %%
import pandas as pd
from matplotlib import pyplot as plt
import os
import numpy as np

# %%
data_dir = "data/processed"

data_files = os.listdir(data_dir)

# %%
print(data_files)
# Out:
# ['historical_GHG_Sectors_GCP.csv', 'historical_GHG_Sectors_PIK.csv', 'historical_GHG_Sectors_UNFCCC.csv', 'mobility_apple.csv', 'mobility_citymapper.csv', 'mobility_google.csv', 'uk_energy_daily.csv']

# %% [markdown]
# ## Define import processes
#
# The idea is that all data sets are read and will all be indexed by a DateTime series and possibly other indices if helpful.

# %%
def read_multi_indexed_csv(file_in, first_data_column, dir_in=data_dir):
    ''' Read in preprocessed historical GHG data.

    Arguments:
        file_in (str): Name of file
        first_data_column (str|int) : index or name of first column with data
        dir_in (str): Directory of file
    
    Returns
        (DataFrame, list): The data of the file loaded in a dataframe
        and a list indicating which columns contain the data of interest
    '''
    if not (
        isinstance(first_data_column, type(str()))
        or isinstance(first_data_column, type(int()))
    ) :
        raise TypeError("`first_data_column` must be a column name or an int")

    file_path = os.path.join(dir_in, file_in)
    df = pd.read_csv(file_path)
    index_cols = [c for c in df.columns if c + '.1' in df.columns]
    
    for col in ["date", "Date", "timestamp"]:
        if col in df:
            df[col] = pd.to_datetime(df[col])
    
    if index_cols:
        df.drop([f"{c}.1" for c in index_cols], axis=1, inplace=True)
        df.set_index(
            pd.MultiIndex.from_frame(df[index_cols]), inplace=True
        )

    if isinstance(first_data_column, type(str())):
        first_data_column = df.columns.get_loc(first_data_column)
        
    data_fields = df.columns[first_data_column:]
    return (df, data_fields)

# %% [markdown]
# ### historical green house gas emissions
#
#
# define `read_historical_GHG`

# %%
def read_historical_GHG(file_in, dir_in=data_dir):
    ''' Read in preprocessed historical GHG data.

    Arguments:
        file_in (str): Name of file
        dir_in (str): Directory of file
    
    Returns
        (DataFrame, list): The data of the file loaded in a dataframe
        and a list indicating which columns contain the data of interest
    '''
    return read_multi_indexed_csv(file_in, 6, dir_in=data_dir)

# %% [markdown]
# ### Read mobility data
#
#
# define `read_mobility_file`

# %%
def read_mobility_google(file_in, dir_in=data_dir):
    return read_multi_indexed_csv(
        file_in, 
        'retail_and_recreation_percent_change_from_baseline',
        dir_in=data_dir
    )

def read_mobility_apple(file_in, dir_in=data_dir):
    return read_multi_indexed_csv(
        file_in, 
        'driving',
        dir_in=data_dir
    )

def read_mobility_citymapper(file_in, dir_in=data_dir):
    df, col = read_multi_indexed_csv(
        file_in, 1, dir_in=data_dir
    )
    return df.set_index('Date', drop=False), col

# %% [markdown]
# ### load uk energy
#
#
# define `read_uk_energy`

# %%
def read_uk_energy(file_in, dir_in=data_dir):
    df, col = read_multi_indexed_csv(
        file_in, 1, dir_in=data_dir
    )
    return df.set_index('timestamp', drop=False), col

# %% [markdown]
# ## Read in the data
#
# Now we map each file to the appropriate function

# %%
# Map files to a function that will read it properly
file_read_functions = {
    'historical_GHG_Sectors_GCP.csv': read_historical_GHG,
    'historical_GHG_Sectors_PIK.csv': read_historical_GHG,
    'historical_GHG_Sectors_UNFCCC.csv': read_historical_GHG,
    'mobility_apple.csv': read_mobility_apple,
    'mobility_citymapper.csv': read_mobility_citymapper,
    'mobility_google.csv': read_mobility_google,
    'uk_energy_daily.csv': read_uk_energy,
}

# %% [markdown]
# And with a single loop all the different data sets are loaded.

# %%
data_files = os.listdir(data_dir)

data_sets = {}
data_columns = {}
for data_file in data_files:
    data_name, _ = os.path.splitext(data_file)
    data_sets[data_name], data_columns[data_name] = \
        file_read_functions[data_file](data_file)

# %% [markdown]
# ### Summary of available data

# %%
for data in data_sets:
    print("=========================================")
    print(data)
    print("--------------------------------------")
    print(data_columns[data])
    print("--------------------------------------")
    print(data_sets[data].info())
    print("--------------------------------------")
    print()
# Out:
# =========================================
# historical_GHG_Sectors_GCP
# --------------------------------------
# Index(['Bunkers', 'Cement', 'Coal', 'Gas', 'Gas flaring', 'Oil',
#        'Total fossil fuels and cement'],
#       dtype='object')
# --------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 11502 entries, ('Afghanistan', 'CO2', Timestamp('1960-01-01 00:00:00')) to ('Zimbabwe', 'CO2', Timestamp('2018-01-01 00:00:00'))
# Data columns (total 13 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        11502 non-null  object
#  1   GH_Gas                         11502 non-null  object
#  2   date                           11502 non-null  datetime64[ns]
#  3   Data source                    11502 non-null  object
#  4   Unit                           11502 non-null  object
#  5   max_year                       11502 non-null  int64
#  6   Bunkers                        59 non-null     float64
#  7   Cement                         11355 non-null  float64
#  8   Coal                           11394 non-null  float64
#  9   Gas                            11394 non-null  float64
#  10  Gas flaring                    11394 non-null  float64
#  11  Oil                            11394 non-null  float64
#  12  Total fossil fuels and cement  11394 non-null  float64
# dtypes: datetime64[ns](1), float64(7), int64(1), object(4)
# memory usage: 1.2+ MB
# None
# --------------------------------------
#
# =========================================
# historical_GHG_Sectors_PIK
# --------------------------------------
# Index(['Agriculture', 'Energy', 'Industrial Processes and Product Use',
#        'Other', 'Total excluding LULUCF', 'Waste'],
#       dtype='object')
# --------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 164936 entries, ('Afghanistan', 'CH4', Timestamp('1850-01-01 00:00:00')) to ('Zimbabwe', 'N2O', Timestamp('2017-01-01 00:00:00'))
# Data columns (total 12 columns):
#  #   Column                                Non-Null Count   Dtype
# ---  ------                                --------------   -----
#  0   Country                               164936 non-null  object
#  1   GH_Gas                                164936 non-null  object
#  2   date                                  164936 non-null  datetime64[ns]
#  3   Data source                           164936 non-null  object
#  4   Unit                                  164936 non-null  object
#  5   max_year                              164936 non-null  int64
#  6   Agriculture                           136248 non-null  float64
#  7   Energy                                143640 non-null  float64
#  8   Industrial Processes and Product Use  144787 non-null  float64
#  9   Other                                 75936 non-null   float64
#  10  Total excluding LULUCF                164936 non-null  float64
#  11  Waste                                 120120 non-null  float64
# dtypes: datetime64[ns](1), float64(6), int64(1), object(4)
# memory usage: 15.9+ MB
# None
# --------------------------------------
#
# =========================================
# historical_GHG_Sectors_UNFCCC
# --------------------------------------
# Index(['Agriculture', 'Energy', 'Industrial Processes',
#        'Land-Use Change and Forestry', 'Other',
#        'Solvent and Other Product Use', 'Total GHG emissions with LULUCF',
#        'Total GHG emissions without LULUCF', 'Waste'],
#       dtype='object')
# --------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 2121 entries, ('Afghanistan', 'Aggregate GHGs', Timestamp('2005-01-01 00:00:00')) to ('Zimbabwe', 'Aggregate GHGs', Timestamp('2006-01-01 00:00:00'))
# Data columns (total 15 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Country                             2121 non-null   object
#  1   GH_Gas                              2121 non-null   object
#  2   date                                2121 non-null   datetime64[ns]
#  3   Data source                         2121 non-null   object
#  4   Unit                                2121 non-null   object
#  5   max_year                            2121 non-null   int64
#  6   Agriculture                         2035 non-null   float64
#  7   Energy                              2079 non-null   float64
#  8   Industrial Processes                1967 non-null   float64
#  9   Land-Use Change and Forestry        2019 non-null   float64
#  10  Other                               103 non-null    float64
#  11  Solvent and Other Product Use       64 non-null     float64
#  12  Total GHG emissions with LULUCF     2095 non-null   float64
#  13  Total GHG emissions without LULUCF  2065 non-null   float64
#  14  Waste                               2051 non-null   float64
# dtypes: datetime64[ns](1), float64(9), int64(1), object(4)
# memory usage: 258.8+ KB
# None
# --------------------------------------
#
# =========================================
# mobility_apple
# --------------------------------------
# Index(['driving', 'transit', 'walking'], dtype='object')
# --------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 147532 entries, ('city_Aachen_North Rhine-Westphalia_Germany', Timestamp('2020-01-13 00:00:00')) to ('sub-region_Žilina Region__Slovaki', Timestamp('2020-06-14 00:00:00'))
# Data columns (total 9 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   unique_geo_id  147532 non-null  object
#  1   date           147532 non-null  datetime64[ns]
#  2   geo_type       147532 non-null  object
#  3   region         147532 non-null  object
#  4   sub-region     39424 non-null   object
#  5   country        137830 non-null  object
#  6   driving        139688 non-null  float64
#  7   transit        33744 non-null   float64
#  8   walking        53960 non-null   float64
# dtypes: datetime64[ns](1), float64(3), object(5)
# memory usage: 10.7+ MB
# None
# --------------------------------------
#
# =========================================
# mobility_citymapper
# --------------------------------------
# Index(['Amsterdam', 'Barcelona', 'Berlin', 'Birmingham', 'Boston', 'Brussels',
#        'Chicago', 'Copenhagen', 'Hamburg', 'Hong Kong', 'Istanbul', 'Lisbon',
#        'London', 'Los Angeles', 'Lyon', 'Madrid', 'Manchester', 'Melbourne',
#        'Mexico City', 'Milan', 'Monaco', 'Montréal', 'Moscow', 'New York City',
#        'Paris', 'Philadelphia', 'Rhine-Ruhr', 'Rome', 'San Francisco',
#        'Seattle', 'Seoul', 'Singapore', 'St. Petersburg', 'Stockholm',
#        'Sydney', 'São Paulo', 'Tokyo', 'Toronto', 'Vancouver', 'Vienna',
#        'Washington DC'],
#       dtype='object')
# --------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 148 entries, 2020-01-20 to 2020-06-15
# Data columns (total 42 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            148 non-null    datetime64[ns]
#  1   Amsterdam       106 non-null    float64
#  2   Barcelona       106 non-null    float64
#  3   Berlin          106 non-null    float64
#  4   Birmingham      106 non-null    float64
#  5   Boston          106 non-null    float64
#  6   Brussels        106 non-null    float64
#  7   Chicago         106 non-null    float64
#  8   Copenhagen      106 non-null    float64
#  9   Hamburg         113 non-null    float64
#  10  Hong Kong       148 non-null    float64
#  11  Istanbul        106 non-null    float64
#  12  Lisbon          106 non-null    float64
#  13  London          106 non-null    float64
#  14  Los Angeles     106 non-null    float64
#  15  Lyon            113 non-null    float64
#  16  Madrid          106 non-null    float64
#  17  Manchester      106 non-null    float64
#  18  Melbourne       106 non-null    float64
#  19  Mexico City     106 non-null    float64
#  20  Milan           120 non-null    float64
#  21  Monaco          120 non-null    float64
#  22  Montréal        106 non-null    float64
#  23  Moscow          106 non-null    float64
#  24  New York City   106 non-null    float64
#  25  Paris           106 non-null    float64
#  26  Philadelphia    106 non-null    float64
#  27  Rhine-Ruhr      113 non-null    float64
#  28  Rome            113 non-null    float64
#  29  San Francisco   113 non-null    float64
#  30  Seattle         113 non-null    float64
#  31  Seoul           134 non-null    float64
#  32  Singapore       134 non-null    float64
#  33  St. Petersburg  106 non-null    float64
#  34  Stockholm       106 non-null    float64
#  35  Sydney          106 non-null    float64
#  36  São Paulo       106 non-null    float64
#  37  Tokyo           141 non-null    float64
#  38  Toronto         106 non-null    float64
#  39  Vancouver       106 non-null    float64
#  40  Vienna          106 non-null    float64
#  41  Washington DC   106 non-null    float64
# dtypes: datetime64[ns](1), float64(41)
# memory usage: 49.7 KB
# None
# --------------------------------------
#
# =========================================
# mobility_google
# --------------------------------------
# Index(['retail_and_recreation_percent_change_from_baseline',
#        'grocery_and_pharmacy_percent_change_from_baseline',
#        'parks_percent_change_from_baseline',
#        'transit_stations_percent_change_from_baseline',
#        'workplaces_percent_change_from_baseline',
#        'residential_percent_change_from_baseline'],
#       dtype='object')
# --------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 227699 entries, ('AE_United Arab Emirates', Timestamp('2020-02-15 00:00:00')) to ('ZW_Zimbabwe_Midlands Province_nan_ZW-MI', Timestamp('2020-06-12 00:00:00'))
# Data columns (total 14 columns):
#  #   Column                                              Non-Null Count   Dtype
# ---  ------                                              --------------   -----
#  0   unique_geo_id                                       227699 non-null  object
#  1   date                                                227699 non-null  datetime64[ns]
#  2   country_region_code                                 226767 non-null  object
#  3   country_region                                      227699 non-null  object
#  4   sub_region_1                                        211634 non-null  object
#  5   sub_region_2                                        0 non-null       float64
#  6   iso_3166_2_code                                     195608 non-null  object
#  7   census_fips_code                                    119 non-null     float64
#  8   retail_and_recreation_percent_change_from_baseline  195161 non-null  float64
#  9   grocery_and_pharmacy_percent_change_from_baseline   191766 non-null  float64
#  10  parks_percent_change_from_baseline                  174245 non-null  float64
#  11  transit_stations_percent_change_from_baseline       169409 non-null  float64
#  12  workplaces_percent_change_from_baseline             225054 non-null  float64
#  13  residential_percent_change_from_baseline            158496 non-null  float64
# dtypes: datetime64[ns](1), float64(8), object(5)
# memory usage: 25.0+ MB
# None
# --------------------------------------
#
# =========================================
# uk_energy_daily
# --------------------------------------
# Index(['demand', 'coal', 'nuclear', 'ccgt', 'wind', 'pumped', 'hydro',
#        'biomass', 'oil', 'solar', 'ocgt', 'other'],
#       dtype='object')
# --------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3310 entries, 2011-05-27 to 2020-06-17
# Data columns (total 13 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   timestamp  3310 non-null   datetime64[ns]
#  1   demand     3310 non-null   float64
#  2   coal       3310 non-null   float64
#  3   nuclear    3310 non-null   float64
#  4   ccgt       3310 non-null   float64
#  5   wind       3310 non-null   float64
#  6   pumped     3310 non-null   float64
#  7   hydro      3310 non-null   float64
#  8   biomass    3310 non-null   float64
#  9   oil        3310 non-null   float64
#  10  solar      3310 non-null   float64
#  11  ocgt       3310 non-null   float64
#  12  other      3310 non-null   float64
# dtypes: datetime64[ns](1), float64(12)
# memory usage: 362.0 KB
# None
# --------------------------------------
