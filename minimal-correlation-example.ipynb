# %% [markdown]
# # Summarising the data fitting process in 4 cells
#
# This file shows a minimal working example of the correlation framework . This minimal example serves to illustrate the extensibility of this framework to other data sources.
#
# The correlation framework follows 4 steps:
#
# + data extraction;
# + data recombination;
# + correlation;
# + and prediction.
#
# Additional info:
#
# + data preparation: datasets are in [`data/processed`](data/processed), and are generated by the notebooks in folder [`data/`](data/);
# + visualisation: [`data_viz`](data_viz.ipynb)
# + In depth correlation [`correlate`](correlate.ipynb)

# %%
# Single include needed
import brsflufight_nerc2 as bff2

# %% [markdown]
# ## Data extraction

# %%
data_sets = bff2.load_data_files()

country = 'United Kingdom'
d_uk = data_sets.get_country(country)
# Out:
# WARNING: "PublicData_Countries_v6.xlsx" not found in dictionary `file_read_functions`.
# A loading function must be defined in `data_access.default_file_read_functions`.
# Success: historical_GHG_Sectors_GCP
# Success: historical_GHG_Sectors_PIK
# Success: historical_GHG_Sectors_UNFCCC
# Success: mobility_apple
# Failed: United Kingdom not in mobility_citymapper
# Success: mobility_google
# Success: uk_energy_daily
# Success: uk_energy_demand_reduction

# %% [markdown]
# ## Data recombination

# %%
# Data recombination
d_uk['uk_energy_yearly'] = bff2.summarise_to_freq(
    d_uk['uk_energy_daily'],
    freq='1Y', 
    fun_test_data=lambda gr: gr.count()["dayofyear"]>350,
)
d_uk['uk_energy_demand_reduction_yearly'] = bff2.summarise_to_freq(
    d_uk['uk_energy_demand_reduction'], freq='1Y', fun_test_data=None
)

d_uk['historical_GHG_Sectors_GCP']['Gas and Coal (CO2)'] = \
    d_uk['historical_GHG_Sectors_GCP']['Gas (CO2)'] \
    + d_uk['historical_GHG_Sectors_GCP']['Coal (CO2)']

# %% [markdown]
# ## Correlation

# %%
to_correlate = {
    'uk_energy_yearly': ['oil', 'ccgt', 'coal', 'demand'],  # Carbon power generation
    'historical_GHG_Sectors_GCP': [  # Select only CO2 data not other gases
        s for s in d_uk['historical_GHG_Sectors_GCP'].columns if f"(CO2)" in s
    ],
    'historical_GHG_Sectors_PIK': [  # Select Energy data not other sectors
        'Energy (KYOTOGHG)', 'Energy (CO2)', 'Energy (N2O)', 'Energy (CH4)'
    ],
}

correlation_dict = bff2.correlate(
    selector=to_correlate,  # datasets defined above
    data_sets=d_uk,  # UK data
    main_compare='uk_energy_yearly',  # reference dataset, the other are correlated to it
)

bff2.display_correlations(correlation_dict, display_fun=display)
# Out:
# Linear regression failed for: 'Bunkers (CO2)' fit to  'oil':
#   Message: Input contains NaN, infinity or a value too large for dtype('float64').
# Linear regression failed for: 'Bunkers (CO2)' fit to  'ccgt':
#   Message: Input contains NaN, infinity or a value too large for dtype('float64').
# Linear regression failed for: 'Bunkers (CO2)' fit to  'coal':
#   Message: Input contains NaN, infinity or a value too large for dtype('float64').
# Linear regression failed for: 'Bunkers (CO2)' fit to  'demand':
#   Message: Input contains NaN, infinity or a value too large for dtype('float64').
# =====================================================================
# Pearson correlation coefficients in dataset 'historical_GHG_Sectors_GCP'
# 	 on data from 2012 to 2018 (inclusive)
# _________________________________________________________
# <style  type="text/css" >
#     #T_13a67f24_b25d_11ea_b4d8_f8e4e3d5f2f4row0_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_13a67f24_b25d_11ea_b4d8_f8e4e3d5f2f4row0_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_13a67f24_b25d_11ea_b4d8_f8e4e3d5f2f4row0_col2 {
#             background-color:  #034973;
#             color:  #f1f1f1;
#         }    #T_13a67f24_b25d_11ea_b4d8_f8e4e3d5f2f4row0_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_13a67f24_b25d_11ea_b4d8_f8e4e3d5f2f4row0_col4 {
#             background-color:  #f6eff7;
#             color:  #000000;
#         }    #T_13a67f24_b25d_11ea_b4d8_f8e4e3d5f2f4row0_col5 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_13a67f24_b25d_11ea_b4d8_f8e4e3d5f2f4row0_col6 {
#             background-color:  #034973;
#             color:  #f1f1f1;
#         }    #T_13a67f24_b25d_11ea_b4d8_f8e4e3d5f2f4row0_col7 {
#             background-color:  #034973;
#             color:  #f1f1f1;
#         }    #T_13a67f24_b25d_11ea_b4d8_f8e4e3d5f2f4row1_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_13a67f24_b25d_11ea_b4d8_f8e4e3d5f2f4row1_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_13a67f24_b25d_11ea_b4d8_f8e4e3d5f2f4row1_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_13a67f24_b25d_11ea_b4d8_f8e4e3d5f2f4row1_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_13a67f24_b25d_11ea_b4d8_f8e4e3d5f2f4row1_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_13a67f24_b25d_11ea_b4d8_f8e4e3d5f2f4row1_col5 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_13a67f24_b25d_11ea_b4d8_f8e4e3d5f2f4row1_col6 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_13a67f24_b25d_11ea_b4d8_f8e4e3d5f2f4row1_col7 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_13a67f24_b25d_11ea_b4d8_f8e4e3d5f2f4row2_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_13a67f24_b25d_11ea_b4d8_f8e4e3d5f2f4row2_col1 {
#             background-color:  #f1ebf5;
#             color:  #000000;
#         }    #T_13a67f24_b25d_11ea_b4d8_f8e4e3d5f2f4row2_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_13a67f24_b25d_11ea_b4d8_f8e4e3d5f2f4row2_col3 {
#             background-color:  #faf3f9;
#             color:  #000000;
#         }    #T_13a67f24_b25d_11ea_b4d8_f8e4e3d5f2f4row2_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_13a67f24_b25d_11ea_b4d8_f8e4e3d5f2f4row2_col5 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_13a67f24_b25d_11ea_b4d8_f8e4e3d5f2f4row2_col6 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_13a67f24_b25d_11ea_b4d8_f8e4e3d5f2f4row2_col7 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_13a67f24_b25d_11ea_b4d8_f8e4e3d5f2f4row3_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_13a67f24_b25d_11ea_b4d8_f8e4e3d5f2f4row3_col1 {
#             background-color:  #f1ebf5;
#             color:  #000000;
#         }    #T_13a67f24_b25d_11ea_b4d8_f8e4e3d5f2f4row3_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_13a67f24_b25d_11ea_b4d8_f8e4e3d5f2f4row3_col3 {
#             background-color:  #faf3f9;
#             color:  #000000;
#         }    #T_13a67f24_b25d_11ea_b4d8_f8e4e3d5f2f4row3_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_13a67f24_b25d_11ea_b4d8_f8e4e3d5f2f4row3_col5 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_13a67f24_b25d_11ea_b4d8_f8e4e3d5f2f4row3_col6 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_13a67f24_b25d_11ea_b4d8_f8e4e3d5f2f4row3_col7 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }</style><table id="T_13a67f24_b25d_11ea_b4d8_f8e4e3d5f2f4" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Bunkers (CO2)</th>        <th class="col_heading level0 col1" >Cement (CO2)</th>        <th class="col_heading level0 col2" >Coal (CO2)</th>        <th class="col_heading level0 col3" >Gas (CO2)</th>        <th class="col_heading level0 col4" >Gas flaring (CO2)</th>        <th class="col_heading level0 col5" >Oil (CO2)</th>        <th class="col_heading level0 col6" >Total fossil fuels and cement (CO2)</th>        <th class="col_heading level0 col7" >Gas and Coal (CO2)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_13a67f24_b25d_11ea_b4d8_f8e4e3d5f2f4level0_row0" class="row_heading level0 row0" >oil</th>
#                         <td id="T_13a67f24_b25d_11ea_b4d8_f8e4e3d5f2f4row0_col0" class="data row0 col0" >nan</td>
#                         <td id="T_13a67f24_b25d_11ea_b4d8_f8e4e3d5f2f4row0_col1" class="data row0 col1" >-0.845</td>
#                         <td id="T_13a67f24_b25d_11ea_b4d8_f8e4e3d5f2f4row0_col2" class="data row0 col2" >0.883</td>
#                         <td id="T_13a67f24_b25d_11ea_b4d8_f8e4e3d5f2f4row0_col3" class="data row0 col3" >-0.613</td>
#                         <td id="T_13a67f24_b25d_11ea_b4d8_f8e4e3d5f2f4row0_col4" class="data row0 col4" >-0.700</td>
#                         <td id="T_13a67f24_b25d_11ea_b4d8_f8e4e3d5f2f4row0_col5" class="data row0 col5" >-0.883</td>
#                         <td id="T_13a67f24_b25d_11ea_b4d8_f8e4e3d5f2f4row0_col6" class="data row0 col6" >0.883</td>
#                         <td id="T_13a67f24_b25d_11ea_b4d8_f8e4e3d5f2f4row0_col7" class="data row0 col7" >0.883</td>
#             </tr>
#             <tr>
#                         <th id="T_13a67f24_b25d_11ea_b4d8_f8e4e3d5f2f4level0_row1" class="row_heading level0 row1" >ccgt</th>
#                         <td id="T_13a67f24_b25d_11ea_b4d8_f8e4e3d5f2f4row1_col0" class="data row1 col0" >nan</td>
#                         <td id="T_13a67f24_b25d_11ea_b4d8_f8e4e3d5f2f4row1_col1" class="data row1 col1" >0.739</td>
#                         <td id="T_13a67f24_b25d_11ea_b4d8_f8e4e3d5f2f4row1_col2" class="data row1 col2" >-0.786</td>
#                         <td id="T_13a67f24_b25d_11ea_b4d8_f8e4e3d5f2f4row1_col3" class="data row1 col3" >0.643</td>
#                         <td id="T_13a67f24_b25d_11ea_b4d8_f8e4e3d5f2f4row1_col4" class="data row1 col4" >0.487</td>
#                         <td id="T_13a67f24_b25d_11ea_b4d8_f8e4e3d5f2f4row1_col5" class="data row1 col5" >0.857</td>
#                         <td id="T_13a67f24_b25d_11ea_b4d8_f8e4e3d5f2f4row1_col6" class="data row1 col6" >-0.786</td>
#                         <td id="T_13a67f24_b25d_11ea_b4d8_f8e4e3d5f2f4row1_col7" class="data row1 col7" >-0.786</td>
#             </tr>
#             <tr>
#                         <th id="T_13a67f24_b25d_11ea_b4d8_f8e4e3d5f2f4level0_row2" class="row_heading level0 row2" >coal</th>
#                         <td id="T_13a67f24_b25d_11ea_b4d8_f8e4e3d5f2f4row2_col0" class="data row2 col0" >nan</td>
#                         <td id="T_13a67f24_b25d_11ea_b4d8_f8e4e3d5f2f4row2_col1" class="data row2 col1" >-0.703</td>
#                         <td id="T_13a67f24_b25d_11ea_b4d8_f8e4e3d5f2f4row2_col2" class="data row2 col2" >1.000</td>
#                         <td id="T_13a67f24_b25d_11ea_b4d8_f8e4e3d5f2f4row2_col3" class="data row2 col3" >-0.571</td>
#                         <td id="T_13a67f24_b25d_11ea_b4d8_f8e4e3d5f2f4row2_col4" class="data row2 col4" >-0.775</td>
#                         <td id="T_13a67f24_b25d_11ea_b4d8_f8e4e3d5f2f4row2_col5" class="data row2 col5" >-0.786</td>
#                         <td id=
# =====================================================================
#
# =====================================================================
# Pearson correlation coefficients in dataset 'historical_GHG_Sectors_PIK'
# 	 on data from 2012 to 2017 (inclusive)
# _________________________________________________________
# <style  type="text/css" >
#     #T_13a853be_b25d_11ea_969d_f8e4e3d5f2f4row0_col0 {
#             background-color:  #023a5b;
#             color:  #f1f1f1;
#         }    #T_13a853be_b25d_11ea_969d_f8e4e3d5f2f4row0_col1 {
#             background-color:  #023a5b;
#             color:  #f1f1f1;
#         }    #T_13a853be_b25d_11ea_969d_f8e4e3d5f2f4row0_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_13a853be_b25d_11ea_969d_f8e4e3d5f2f4row0_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_13a853be_b25d_11ea_969d_f8e4e3d5f2f4row1_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_13a853be_b25d_11ea_969d_f8e4e3d5f2f4row1_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_13a853be_b25d_11ea_969d_f8e4e3d5f2f4row1_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_13a853be_b25d_11ea_969d_f8e4e3d5f2f4row1_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_13a853be_b25d_11ea_969d_f8e4e3d5f2f4row2_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_13a853be_b25d_11ea_969d_f8e4e3d5f2f4row2_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_13a853be_b25d_11ea_969d_f8e4e3d5f2f4row2_col2 {
#             background-color:  #023e62;
#             color:  #f1f1f1;
#         }    #T_13a853be_b25d_11ea_969d_f8e4e3d5f2f4row2_col3 {
#             background-color:  #023d60;
#             color:  #f1f1f1;
#         }    #T_13a853be_b25d_11ea_969d_f8e4e3d5f2f4row3_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_13a853be_b25d_11ea_969d_f8e4e3d5f2f4row3_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_13a853be_b25d_11ea_969d_f8e4e3d5f2f4row3_col2 {
#             background-color:  #023e62;
#             color:  #f1f1f1;
#         }    #T_13a853be_b25d_11ea_969d_f8e4e3d5f2f4row3_col3 {
#             background-color:  #023d60;
#             color:  #f1f1f1;
#         }</style><table id="T_13a853be_b25d_11ea_969d_f8e4e3d5f2f4" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Energy (KYOTOGHG)</th>        <th class="col_heading level0 col1" >Energy (CO2)</th>        <th class="col_heading level0 col2" >Energy (N2O)</th>        <th class="col_heading level0 col3" >Energy (CH4)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_13a853be_b25d_11ea_969d_f8e4e3d5f2f4level0_row0" class="row_heading level0 row0" >oil</th>
#                         <td id="T_13a853be_b25d_11ea_969d_f8e4e3d5f2f4row0_col0" class="data row0 col0" >0.986</td>
#                         <td id="T_13a853be_b25d_11ea_969d_f8e4e3d5f2f4row0_col1" class="data row0 col1" >0.986</td>
#                         <td id="T_13a853be_b25d_11ea_969d_f8e4e3d5f2f4row0_col2" class="data row0 col2" >0.812</td>
#                         <td id="T_13a853be_b25d_11ea_969d_f8e4e3d5f2f4row0_col3" class="data row0 col3" >0.986</td>
#             </tr>
#             <tr>
#                         <th id="T_13a853be_b25d_11ea_969d_f8e4e3d5f2f4level0_row1" class="row_heading level0 row1" >ccgt</th>
#                         <td id="T_13a853be_b25d_11ea_969d_f8e4e3d5f2f4row1_col0" class="data row1 col0" >-0.829</td>
#                         <td id="T_13a853be_b25d_11ea_969d_f8e4e3d5f2f4row1_col1" class="data row1 col1" >-0.829</td>
#                         <td id="T_13a853be_b25d_11ea_969d_f8e4e3d5f2f4row1_col2" class="data row1 col2" >-0.829</td>
#                         <td id="T_13a853be_b25d_11ea_969d_f8e4e3d5f2f4row1_col3" class="data row1 col3" >-0.886</td>
#             </tr>
#             <tr>
#                         <th id="T_13a853be_b25d_11ea_969d_f8e4e3d5f2f4level0_row2" class="row_heading level0 row2" >coal</th>
#                         <td id="T_13a853be_b25d_11ea_969d_f8e4e3d5f2f4row2_col0" class="data row2 col0" >1.000</td>
#                         <td id="T_13a853be_b25d_11ea_969d_f8e4e3d5f2f4row2_col1" class="data row2 col1" >1.000</td>
#                         <td id="T_13a853be_b25d_11ea_969d_f8e4e3d5f2f4row2_col2" class="data row2 col2" >0.771</td>
#                         <td id="T_13a853be_b25d_11ea_969d_f8e4e3d5f2f4row2_col3" class="data row2 col3" >0.943</td>
#             </tr>
#             <tr>
#                         <th id="T_13a853be_b25d_11ea_969d_f8e4e3d5f2f4level0_row3" class="row_heading level0 row3" >demand</th>
#                         <td id="T_13a853be_b25d_11ea_969d_f8e4e3d5f2f4row3_col0" class="data row3 col0" >1.000</td>
#                         <td id="T_13a853be_b25d_11ea_969d_f8e4e3d5f2f4row3_col1" class="data row3 col1" >1.000</td>
#                         <td id="T_13a853be_b25d_11ea_969d_f8e4e3d5f2f4row3_col2" class="data row3 col2" >0.771</td>
#                         <td id="T_13a853be_b25d_11ea_969d_f8e4e3d5f2f4row3_col3" class="data row3 col3" >0.943</td>
#             </tr>
#     </tbody></table>
# =====================================================================

# %% [markdown]
# ## Prediction

# %%
prediction, change_corona = bff2.predict_correlation_model(
    d_uk['uk_energy_demand_reduction_yearly'],
    correlation_dict['historical_GHG_Sectors_PIK'],
)

display(change_corona)
# Out:
#             predictor_value  Energy (KYOTOGHG)  Energy (CO2)  Energy (N2O)  \
# date
# 2020-01-01     -3741.930094         -76.637021    -74.360175     -0.094797
# 2020-01-01        -0.117657          -0.199307     -0.198163     -0.037639
#
#             Energy (CH4)             quantity
# date
# 2020-01-01     -1.903151  absolute difference
# 2020-01-01     -0.273903  relative difference
